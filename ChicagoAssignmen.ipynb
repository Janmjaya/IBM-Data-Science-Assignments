# %%
# %reload_ext sql

# %%
# %sql ibm_db_sa://sdw43109:z-qr1j2pvs81zjz6@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: [IBM][CLI Driver] SQL0438N  Application raised error or warning with diagnostic text: "Exceeded maximum limit of 5 connections. Connection refused".  SQLSTATE=42502 SQLCODE=-438 (Background on this error at: http://sqlalche.me/e/f405)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB'])

# %%
# %sql select count(*) from CENSUS_DATA;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('78'),)]

# %%
# %sql select count(*) from CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('566'),)]

# %%
# %sql select count(*) from CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql SELECT * from CHICAGO_PUBLIC_SCHOOLS LIMIT 2;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql SELECT * from CENSUS_DATA LIMIT 2;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(1, 'Rogers Park', Decimal('7.7'), Decimal('23.6'), Decimal('8.7'), Decimal('18.2'), Decimal('27.5'), 23939, 39),
#  (2, 'West Ridge', Decimal('7.8'), Decimal('17.2'), Decimal('8.8'), Decimal('20.8'), Decimal('38.5'), 23040, 46)]

# %%
# %sql select Communit_Area_Number from CENSUS_DATA;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "COMMUNIT_AREA_NUMBER" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: 'select Communit_Area_Number from CENSUS_DATA;'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from syscat.tables where tabschema='SDW43109'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('SDW43109', 'CENSUS_DATA', datetime.datetime(2018, 9, 2, 1, 48, 51, 936370)),
#  ('SDW43109', 'CHICAGO_CRIME_DATA', datetime.datetime(2018, 9, 2, 1, 50, 9, 118424)),
#  ('SDW43109', 'CHICAGO_PUBLIC_SCHOOLS', datetime.datetime(2018, 9, 2, 4, 52, 57, 861850)),
#  ('SDW43109', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2018, 9, 1, 16, 49, 15, 448274)),
#  ('SDW43109', 'DEPARTMENTS', datetime.datetime(2018, 9, 1, 10, 54, 48, 396707)),
#  ('SDW43109', 'EMPLOYEES', datetime.datetime(2018, 9, 1, 10, 54, 48, 25926)),
#  ('SDW43109', 'INSTRUCTOR', datetime.datetime(2018, 9, 1, 16, 11, 3, 765073)),
#  ('SDW43109', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2018, 9, 1, 16, 41, 14, 510102)),
#  ('SDW43109', 'JOBS', datetime.datetime(2018, 9, 1, 11, 17, 34, 119633)),
#  ('SDW43109', 'JOB_HISTORY', datetime.datetime(2018, 9, 1, 10, 54, 48, 153562)),
# ...

# %%
# %sql select * from syscat.columns where tabname = 'CHICAGO_PUBLIC_SCHOOLS' limit 2;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('SDW43109', 'CHICAGO_PUBLIC_SCHOOLS', 'Rate_of_Misconducts__per_100_students', 33, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 288, '+0230.6', '+0000.1', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('SDW43109', 'CHICAGO_PUBLIC_SCHOOLS', 'Average_Teacher_Attendance', 34, 'SYSIBM  ', 'VARCHAR', 5, 0, 'OCTETS', 5, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 55, "'98.1%'", "'91.7%'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None)]

# %%
# %sql select * from syscat.columns where tabname = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('SDW43109', 'CENSUS_DATA', 'PER_CAPITA_INCOME', 7, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '71551', '10402', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('SDW43109', 'CENSUS_DATA', 'HARDSHIP_INDEX', 8, 'SYSIBM  ', 'SMALLINT', 2, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 78, '98', '2', 3, None, 0, 20, 10, 1, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select * from syscat.columns where tabname = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('SDW43109', 'CHICAGO_CRIME_DATA', 'ID', 0, 'SYSIBM  ', 'INTEGER', 4, 0, None, None, None, 'Y', 0, None, None, ' ', ' ', 533, '11233321', '23469', 5, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('SDW43109', 'CHICAGO_CRIME_DATA', 'Case_Number', 1, 'SYSIBM  ', 'VARCHAR', 8, 0, 'OCTETS', 8, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 533, "'JB155558'", "'G040244'", 13, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 8, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql select * from syscat.columns where tabname = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('SDW43109', 'CHICAGO_PUBLIC_SCHOOLS', 'Rate_of_Misconducts__per_100_students', 33, 'SYSIBM  ', 'DECIMAL', 5, 1, None, None, None, 'Y', 0, None, None, ' ', ' ', 288, '+0230.6', '+0000.1', 4, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, -1, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
#  ('SDW43109', 'CHICAGO_PUBLIC_SCHOOLS', 'Average_Teacher_Attendance', 34, 'SYSIBM  ', 'VARCHAR', 5, 0, 'OCTETS', 5, None, 'Y', 1208, 'SYSIBM', 'IDENTITY', ' ', ' ', 55, "'98.1%'", "'91.7%'", 10, None, 0, 20, 10, 0, None, None, None, None, None, None, None, None, ' ', 0, -1, 'N', 'N', ' ', None, 'O', None, -1.0, -1, -1, 5, None, None, 'N', 'N', 'N', -1, -1.0, None, None, 'N', None),
# ...

# %%
# %sql SELECT "Community_Area_Name",AVG("College_Enrollment__number_of_students")AS "Average_College_Enrollments"FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "Community_Area_Name" ;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', Decimal('858.000000')),
#  ('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('ARMOUR SQUARE', Decimal('486.000000')),
#  ('ASHBURN', Decimal('810.375000')),
#  ('AUBURN GRESHAM', Decimal('417.500000')),
#  ('AUSTIN', Decimal('475.347826')),
#  ('AVALON PARK', Decimal('507.333333')),
#  ('AVONDALE', Decimal('910.000000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333')),
#  ('BEVERLY', Decimal('409.000000')),
#  ('BRIDGEPORT', Decimal('633.400000')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BURNSIDE', Decimal('549.000000')),
#  ('CALUMET HEIGHTS', Decimal('261.333333')),
#  ('CHATHAM', Decimal('560.222222')),
#  ('CHICAGO LAWN', Decimal('1012.285714')),
#  ('CLEARING', Decimal('521.250000')),
#  ('DOUGLAS', Decimal('424.545454')),
#  ('DUNNING', Decimal('761.333333')),
#  ('EAST GARFIELD PARK', Decimal('410.538461')),
# ...

# %%
# %sql SELECT Count(*) FROM CHICAGO_PUBLIC_SCHOOLS WHERE "Healthy_Schools_Certified" LIKE 'Yes'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('16'),)]

# %%
# %sql SELECT Count(*) FROM CHICAGO_CRIME_DATA WHERE "Location_Description" LIKE 'GAS STATION'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('6'),)]

# %%
# %sql SELECT "Community_Area_Name",COUNT("School_ID")AS"No_Of_Schools" FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "Community_Area_Name" ORDER BY "No_Of_Schools" Desc LIMIT 10;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('AUSTIN', Decimal('23')),
#  ('SOUTH LAWNDALE', Decimal('22')),
#  ('WEST TOWN', Decimal('20')),
#  ('ENGLEWOOD', Decimal('17')),
#  ('NEAR WEST SIDE', Decimal('16')),
#  ('NORTH LAWNDALE', Decimal('16')),
#  ('EAST GARFIELD PARK', Decimal('13')),
#  ('ROSELAND', Decimal('13')),
#  ('NEW CITY', Decimal('13')),
#  ('HUMBOLDT PARK', Decimal('13'))]

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_CRIME_DATA WHERE "Primary_Type" LIKE 'MOTOR VEHICLE THEFT'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('24'),)]

# %%
# %sql select "CPS.Name_of_School","CPS.Average_Student_Attendance" from CHICAGO_PUBLIC_SCHOOLS as CPS INNER JOIN CENSUS_DATA as CD on CPS.Community_Area_Number=CD.Community_Area_Number where CD.HARDSHIP_INDEX ='96'
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "CPS.COMMUNITY_AREA_NUMBER" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: 'select "CPS.Name_of_School","CPS.Average_Student_Attendance" from CHICAGO_PUBLIC_SCHOOLS as CPS INNER JOIN CENSUS_DATA as CD on CPS.Community_Area_Number=CD.Community_Area_Number where CD.HARDSHIP_INDEX =\'96\''] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql select CPS."Name_of_School","Average_Student_Attendance" from CHICAGO_PUBLIC_SCHOOLS AS CPS WHERE "Community_Area_Number" = '30';
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Charles G Hammond Elementary School', '95.3%'),
#  ('Cyrus H McCormick Elementary School', '95.9%'),
#  ('Daniel J Corkery Elementary School', '94.7%'),
#  ('David G Farragut Career Academy High School', '86.1%'),
#  ('Eli Whitney Elementary School', '95.8%'),
#  ('Emiliano Zapata Elementary Academy', '96.6%'),
#  ('Francisco I Madero Middle School', '95.1%'),
#  ('Gerald Delgado Kanoon Elementary Magnet School', '95.9%'),
#  ('Greater Lawndale High School For Social Justice', '87.5%'),
#  ('Ignance Paderewski Elementary Learning Academy', '92.1%'),
#  ('Infinity Math Science and Technology High School', '92.2%'),
#  ('John Spry Elementary Community School', '96.2%'),
#  ('Josefa Ortiz De Dominguez Elementary School', '95.8%'),
#  ('Joseph E Gary Elementary School', '96.1%'),
#  ('Lazaro Cardenas Elementary School', '96.3%'),
#  ('Little Village Elementary School', '96.7%'),
# ...

# %%
# %sql select CPS."Name_of_School",CPS."Average_Student_Attendance" 
from CHICAGO_PUBLIC_SCHOOLS as CPS INNER JOIN CENSUS_DATA as CD on CPS."Community_Area_Number"=CD."Community_Area_Number" 
where CD."HARDSHIP_INDEX" ='96'ORDER BY "Average_Student_Attendance" Asc LIMIT 1;
# Out:
#  * ibm_db_sa://sdw43109:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('David G Farragut Career Academy High School', '86.1%')]
